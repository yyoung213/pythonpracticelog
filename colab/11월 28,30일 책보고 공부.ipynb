# %% [markdown]
# 모듈
#
# 표준모듈
#
# 써드파ㅓ티 모듈
#
# import 구문 사용

# %%
import random
print(random.randint(1,100))
# Out:
# 91

# %%
import random
print(randint(1,100))#모듈명을 명시해야 함
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f06ed9f5177c> in <module>
#       1 import random
# ----> 2 print(randint(1,100))
#
# NameError: name 'randint' is not defined

# %%
import random as rd
print(rd.randint(1,100))
# Out:
# 23

# %%
from random import randint
print(randint(1,100))
# Out:
# 23

# %%
from random import *
print(randint(1,100))

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
import random as rd 

cards=[['A','Spade'],["A",'Club'],['A','Diamond'],['A','Heart']]
rd.shuffle(cards)
print(cards)
print(rd.sample(cards,2))
# Out:
# [['A', 'Heart'], ['A', 'Club'], ['A', 'Diamond'], ['A', 'Spade']]
# [['A', 'Heart'], ['A', 'Club']]

# %%
from collections import deque

deque_list=deque()
for  i in range (5):
    deque_list.append(i)

print(deque_list)
# Out:
# deque([0, 1, 2, 3, 4])

# %%
from collections import deque

deque_list=deque()
for  i in 'ABCDEFGHIJK':
    deque_list.append(i)
    
print(deque_list)
# Out:
# deque(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K'])

# %%
from collections import OderdedDict

# %%
f=open("yesterday.txt",'r')
yesterday_lyric=f.read
f.close()

yesterday_lyric
# Out:
# <function TextIOWrapper.read(size=-1, /)>
