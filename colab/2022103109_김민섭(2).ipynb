# %% [markdown]
# 이름: 김민섭
#
# 학번: 2022103109
#
# 별명: 막내여동생

# %%
#1번



import string#특수문자 제거

region_dict={'서울':3,'경기':5,'충남':15.3,'대전':7.332,'전남':15.459,'경남':7.42,'제주':3.249}
data='기/경:5.257% 남/전:3.449% 주/제:5.3% 원/강:8.8% 전/대:805mm'

new_data=data.split()[0:3]
n2_data=':'.join(new_data)
n3_data=n2_data.split(':')[1:6:2]
table=str.maketrans('%',' ',string.punctuation)
n4_data=''.join(n3_data)
final=n4_data.split('%')[0:3]

final.insert(0,'0')
final.insert(2,'0')
final.insert(3,'0')
final.insert(5,'0')
final

n_final=list(map(int,final))
alist=[]
for i in len(n_final):
    alist[i]=n_final[i]+a[i]

print('---지역별 수확량(%)---')
print('[서울]:', alist[0])
print('[경기]:', alist[1])
print('[충남]:', alist[2])
print('[대전]:', alist[3])
print('[전남]:', alist[4])
print('[경남]:', alist[5])
print('[제주]:', alist[6])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-204918bb36ca> in <module>
#      21 final
#      22
# ---> 23 n_final=list(map(int,final))
#      24
#
# TypeError: 'list' object is not callable

# %%
#2번


import string
import re
from collections import Counter
a=input('총 몇개의 문장을 입력하시겠습니까?')
i=1
sentence=[]
while True:
    b=input(f'{i}번째 문장을 입력하세요:')
    sentence.append(b)
    i= i+1
    if i-1==int(a):
        break
n_sentence=' '.join(sentence)

table=str.maketrans('','',string.punctuation)

n_sentence=n_sentence.translate(table)
#print(n_sentence)
n2_sentence=re.sub(r'\d+','',n_sentence)
#print(n2_sentence)
c=Counter(n2_sentence.lower().split())

print('-'*20)
print('    단어     빈도     ')
print('-'*20)
print(f'{c.keys[1]}       {c.values[1]}')
print(f'{c.keys[2]}       {c.values[2]}')
print(f'{c.keys[3]}       {c.values[3]}')
print(f'{c.keys[4]}       {c.values[4]}')
print(f'{c.keys[5]}       {c.values[5]}')
print(f'{c.keys[6]}       {c.values[6]}')
print(f'{c.keys[7]}       {c.values[7]}')
print(f'{c.keys[8]}       {c.values[8]}')
print(f'{c.keys[9]}       {c.values[9]}')
print(f'{c.keys[10]}       {c.values[10]}')
print(f'{c.keys[11]}       {c.values[11]}')
print(f'{c.keys[12]}       {c.values[12]}')
print(f'{c.keys[13]}       {c.values[13]}')
# Out:
# 총 몇개의 문장을 입력하시겠습니까?3
# 1번째 문장을 입력하세요: yeadkjfhald asdfadk  asdkjfhalsdf
# 2번째 문장을 입력하세요:asd ad aewf
# 3번째 문장을 입력하세요:adfj  afe aesa
# --------------------
#     단어     빈도
# --------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-390b4115e50f> in <module>
#      25 print('-'*20)
#      26
# ---> 27 for b in len(c):
#      28     print(f'{c.keys[b]}       {c.values[b]}')
#
# TypeError: 'int' object is not iterable

# %%
#4번,
std_names=['김대한','김민국','김경희','김한국','김무궁']
stj_names=['수학','영어','국어']

math=[55,30,85,70,90]
eng=[74,65,86,79,100]
kor=[80,90,100,71,62]
sum=[]

for i in range(len(math)):
    sum[i]=(math[i]+eng[i]+kor[i])/3

sum
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-100-57f3b8dc94a7> in <module>
#       8 sum=[]
#       9 for i in range(len(math)):
# ---> 10     sum[i]=(math[i]+eng[i]+kor[i])/3
#      11
#      12 sum
#
# IndexError: list assignment index out of range

# %%
#보너스
ncol=int(input("Number of Arrow Head: "))
nrow=int(input("Number of Arrow Tail: "))
format_str = '{:<'+str(nrow)+'}'
for i in range(1,nrow+1):
    print(' '*int(nrow)+format_str.format("*"*i))
print("*"*(int(nrow)+int(ncol)))
for i in range(nrow,0,-1):
   print(' '*int(nrow)+format_str.format("*"*i))
# Out:
# Number of Arrow Head: 8
# Number of Arrow Tail: 7
#        *
#        **
#        ***
#        ****
#        *****
#        ******
#        *******
# ***************
#        *******
#        ******
#        *****
#        ****
#        ***
#        **
#        *
