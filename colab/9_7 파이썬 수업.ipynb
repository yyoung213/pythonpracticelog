# %% [markdown]
# #Lec02. 변수와 자료형
# ##sub-heading
# ### ssub-heading
#
# **강조**
# ***강조***
# 참조 사이트 [링크 사이트](https://)
#
# - 하나
# - 둘
# - 셋
#
#
# 1. 하나
# 1. 둘
# 1. 셋
#
# $\int_a^b xdx $
#
# $\frac{2}{3}$

# %%
2+3
# Out:
# 5

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# # 새 섹션

# %% [markdown]
# #변수와 자료형
#
#
# 변수와 메모리 - 주소할당 **강의노트 보기**
#
#
# 변수명은 대소문자가 구분된다
#
# name_first 랑 Name_first랑은 다른 변수

# %%
name="Minkyoung Kim"
print(name)
# Out:
# Minkyoung Kim

# %%
a=7
b=5
print(a+b)
# Out:
# 12

# %%
a=7
b=5
print("a+b")
# Out:
# a+b

# %%
first_name="Minkyoung"
last_name="Kim"
full_name=first_name + last_name
print(full_name)
# Out:
# MinkyoungKim

# %% [markdown]
# #자료형과 기본연산
#
# 이진수 한자리 -비트
#
#
# 8비트 - 1바이트
#
# 1024바이트 - 1킬로바이트
#
# 정수형 int
#
# 실수형  float
#
# 문자형  string
#
# 논리형  boolean  --참거짓 판단true false

# %%
a='Hello, "Python!"'
b="Hello, 'Python!'"
print(a)
print(b)
# Out:
# Hello, "Python!"
# Hello, 'Python!'
